# %%
import pandas as pd

df = pd.read_csv("42_registered_cell_towers_cooridnates.csv")
df
# Out:
#                                               Carrier Distance  \
# 0                                         Us Cellular   0.1 mi
# 1                        Winstar Wireless Fiber Corp.   0.2 mi
# 2                                                AT&T   0.2 mi
# 3                                                AT&T   0.2 mi
# 4                                Amfm Operating, Inc.   0.3 mi
# 5                              Union Pacific Railroad   0.3 mi
# 6                              Union Pacific Railroad   0.3 mi
# 7                              Bre 312 Broadcast, Llc   0.4 mi
# 8                              Bre 312 Broadcast, Llc   0.4 mi
# 9                              Union Pacific Railroad   0.4 mi
# 10                                               AT&T   0.4 mi
# 11                                           T-mobile   0.5 mi
# 12                       Trump Commercial Chicago Llc   0.5 mi
# 13                                               AT&T   0.5 mi
# ...

# %%
df.sort_values(by="Carrier")
# Out:
#                                               Carrier Distance  \
# 13                                               AT&T   0.5 mi
# 30                                               AT&T   1.5 mi
# 16                                               AT&T   0.6 mi
# 33                                               AT&T   1.9 mi
# 10                                               AT&T   0.4 mi
# 36                                               AT&T   2.1 mi
# 28                                               AT&T   1.4 mi
# 39                                               AT&T   2.3 mi
# 2                                                AT&T   0.2 mi
# 3                                                AT&T   0.2 mi
# 25                                American Towers Llc   1.2 mi
# 24                                American Towers Llc   1.2 mi
# 37                                American Towers Llc   2.3 mi
# 4                                Amfm Operating, Inc.   0.3 mi
# ...

# %%
df.Carrier.value_counts()
# Out:
# T-mobile                                              11
# AT&T                                                  10
# American Towers Llc                                    3
# Union Pacific Railroad                                 3
# Bre 312 Broadcast, Llc                                 2
# Us Cellular                                            1
# Koziel Llc                                             1
# Sba 2012 Tc Assets, Llc                                1
# Illinois, State Of                                     1
# Northeast Illinois Regional Commuter Railroad Corp     1
# Ccatt Llc                                              1
# Commonwealth Edison Company                            1
# Chicago, City Of                                       1
# Winstar Wireless Fiber Corp.                           1
# Hubbard Radio Chicago, Llc                             1
# Trump Commercial Chicago Llc                           1
# ...

# %%
df_tmobile = df[df.Carrier == "T-mobile"]
#df_tmobile.to_csv("t-mobile.csv")

# %%
df_tmobile.count()
# Out:
# Carrier     11
# Distance    11
# ADD         11
# Lat         11
# Lon         11
# dtype: int64
